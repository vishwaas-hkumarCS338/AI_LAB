# %%
#LAB01 - 30/09/2024
#Q1(B)
#TIC_TAC_TOE GAME USING MACHINE THAT ACTIVELY ATTEMPTS TO BLOCK USER FROM WINNING

import random
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

def check_winner(board):
    for i in range(3):
        if board[i][0] == board[i][1] == board[i][2] != " ":
            return board[i][0]
        if board[0][i] == board[1][i] == board[2][i] != " ":
            return board[0][i]

    if board[0][0] == board[1][1] == board[2][2] != " ":
        return board[0][0]
    if board[0][2] == board[1][1] == board[2][0] != " ":
        return board[0][2]

    return None

def block_win(board):
    # Check rows and columns for blocking
    for i in range(3):
        # Check rows
        if board[i].count("X") == 2 and board[i].count(" ") == 1:
            return (i, board[i].index(" "))
        # Check columns
        column = [board[j][i] for j in range(3)]
        if column.count("X") == 2 and column.count(" ") == 1:
            return (column.index(" "), i)

    # Check diagonals
    if board[0][0] == board[1][1] == "X" and board[2][2] == " ":
        return (2, 2)
    if board[0][2] == board[1][1] == "X" and board[2][0] == " ":
        return (2, 0)

    return None

def is_full(board):
    return all(cell != " " for row in board for cell in row)

def computer_move(board):
    # First try to block the player from winning
    block = block_win(board)
    if block:
        return block  # Return the blocking move

    # If no blocking move, pick a random empty cell
    empty_cells = [(r, c) for r in range(3) for c in range(3) if board[r][c] == " "]
    return random.choice(empty_cells)

def tic_tac_toe():
    board = [[" " for _ in range(3)] for _ in range(3)]

    current_player = "X"  # Player X is the human

    while True:
        print_board(board)

        if current_player == "X":
            row = int(input("Player X, enter your row (0-2): "))
            col = int(input("Player X, enter your column (0-2): "))
        else:
            row, col = computer_move(board)
            print("Computer (O) chooses row " + str(row) + ", column " + str(col))

        if board[row][col] == " ":
            board[row][col] = current_player
        else:
            print("Cell already taken! Try again.")
            continue

        winner = check_winner(board)
        if winner:
            print_board(board)
            print("Player " + winner + " wins!")
            break

        if is_full(board):
            print_board(board)
            print("It's a draw!")
            break

        current_player = "O" if current_player == "X" else "X"

tic_tac_toe()
0
0
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X, enter your row (0-2): 0
# Player X, enter your column (0-2): 1
#   | X |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Computer (O) chooses row 1, column 0
#   | X |
# ---------
# O |   |
# ---------
#   |   |
# ---------
# Player X, enter your row (0-2): 2
# Player X, enter your column (0-2): 1
#   | X |
# ---------
# O |   |
# ---------
#   | X |
# ---------
# Computer (O) chooses row 1, column 1
#   | X |
# ---------
# O | O |
# ---------
#   | X |
# ---------
# Player X, enter your row (0-2): 2
# Player X, enter your column (0-2): 1
# Cell already taken! Try again.
#   | X |
# ---------
# O | O |
# ---------
#   | X |
# ---------
# Player X, enter your row (0-2): 2
# Player X, enter your column (0-2): 2
#   | X |
# ---------
# O | O |
# ---------
#   | X | X
# ---------
# Computer (O) chooses row 2, column 0
#   | X |
# ---------
# O | O |
# ---------
# O | X | X
# ---------
# ...
